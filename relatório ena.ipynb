# %%
import pandas as pd
import matplotlib.pyplot as pt
from src import trata_acomph, regressoes, ena

# %%
ena = ena_mercados()

# %% [markdown]
# # Submercado N

# %%
ena.iloc[0,:].plot()

# %% [markdown]
# # Submercado NE

# %%
ena.iloc[1,:].plot()

# %% [markdown]
# # Submercado S

# %%
pt.plot(ena.iloc[2,:], 'bo')

# %% [markdown]
# # Submercado SE

# %%
ena.iloc[3,:].plot()
